# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import polars as pl
from extdf import Base, IntegerType, RealType
import types
from typing import TypeAlias

# %%
i = Base.from_polars(pl.lit(5), IntegerType())
r = Base.from_polars(pl.lit(5.0), RealType())

# %%
df = pl.DataFrame({"a": []})

# %%
a = RealType()
b = IntegerType()

# %%
def areinstances(objs: tuple[object], classes_or_list: tuple | list[tuple]) -> bool:
    if isinstance(classes_or_list, list):
        return any(areinstances(objs, classes) for classes in classes_or_list)
    
    return all(
        isinstance(obj, cls) for obj, cls in zip(objs, classes_or_list)
    )
